# %%
import pandas as pd
#import geopandas as gpd
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#gpd.read_file('../data/county/tncounty.shp')

# %%
demo_by_state =pd.read_csv('data/household demo by state.csv')
demo_by_state
# Out:
#                                       Label (Grouping) Alabama!!Estimate  \
# 0                                   HOUSEHOLDS BY TYPE               NaN
# 1                                     Total households         2,016,448
# 2                             Married-couple household           941,596
# 3                With children of the householder u...           332,042
# 4                          Cohabiting couple household            94,735
# ..                                                 ...               ...
# 167          West Indian (excluding Hispanic origin...            12,642
# 168                         COMPUTERS AND INTERNET USE               NaN
# 169                                   Total households         2,016,448
# 170                                    With a computer         1,896,102
# 171             With a broadband Internet subscription         1,763,106
#
#     Alabama!!Margin of Error Alabama!!Percent  \
# ...

# %%
demo_by_state.dtypes
# Out:
# Label (Grouping)                         object
# Alabama!!Estimate                        object
# Alabama!!Margin of Error                 object
# Alabama!!Percent                         object
# Alabama!!Percent Margin of Error         object
#                                          ...
# Wyoming!!Percent Margin of Error         object
# Puerto Rico!!Estimate                   float64
# Puerto Rico!!Margin of Error            float64
# Puerto Rico!!Percent                    float64
# Puerto Rico!!Percent Margin of Error    float64
# Length: 209, dtype: object

# %%
demo_by_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Columns: 209 entries, Label (Grouping) to Puerto Rico!!Percent Margin of Error
# dtypes: float64(4), object(205)
# memory usage: 281.0+ KB

# %%
demo_by_state.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Estimate', 'Alabama!!Margin of Error',
#        'Alabama!!Percent', 'Alabama!!Percent Margin of Error',
#        'Alaska!!Estimate', 'Alaska!!Margin of Error', 'Alaska!!Percent',
#        'Alaska!!Percent Margin of Error', 'Arizona!!Estimate',
#        ...
#        'Wisconsin!!Percent', 'Wisconsin!!Percent Margin of Error',
#        'Wyoming!!Estimate', 'Wyoming!!Margin of Error', 'Wyoming!!Percent',
#        'Wyoming!!Percent Margin of Error', 'Puerto Rico!!Estimate',
#        'Puerto Rico!!Margin of Error', 'Puerto Rico!!Percent',
#        'Puerto Rico!!Percent Margin of Error'],
#       dtype='object', length=209)

# %%
demo_state = demo_by_state.drop(columns = ['Alabama!!Margin of Error','Alabama!!Percent Margin of Error', 'Alaska!!Margin of Error','Alaska!!Percent Margin of Error','Wisconsin!!Percent Margin of Error','Wyoming!!Margin of Error','Wyoming!!Percent Margin of Error','Puerto Rico!!Estimate','Puerto Rico!!Margin of Error','Puerto Rico!!Percent','Puerto Rico!!Percent Margin of Error'])
demo_state
# Out:
#                                       Label (Grouping) Alabama!!Estimate  \
# 0                                   HOUSEHOLDS BY TYPE               NaN
# 1                                     Total households         2,016,448
# 2                             Married-couple household           941,596
# 3                With children of the householder u...           332,042
# 4                          Cohabiting couple household            94,735
# ..                                                 ...               ...
# 167          West Indian (excluding Hispanic origin...            12,642
# 168                         COMPUTERS AND INTERNET USE               NaN
# 169                                   Total households         2,016,448
# 170                                    With a computer         1,896,102
# 171             With a broadband Internet subscription         1,763,106
#
#     Alabama!!Percent Alaska!!Estimate Alaska!!Percent Arizona!!Estimate  \
# ...

# %%
demo_by_state.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Estimate', 'Alabama!!Margin of Error',
#        'Alabama!!Percent', 'Alabama!!Percent Margin of Error',
#        'Alaska!!Estimate', 'Alaska!!Margin of Error', 'Alaska!!Percent',
#        'Alaska!!Percent Margin of Error', 'Arizona!!Estimate',
#        ...
#        'Wisconsin!!Percent', 'Wisconsin!!Percent Margin of Error',
#        'Wyoming!!Estimate', 'Wyoming!!Margin of Error', 'Wyoming!!Percent',
#        'Wyoming!!Percent Margin of Error', 'Puerto Rico!!Estimate',
#        'Puerto Rico!!Margin of Error', 'Puerto Rico!!Percent',
#        'Puerto Rico!!Percent Margin of Error'],
#       dtype='object', length=209)

# %%
demo_state = demo_state.drop(columns =['Arizona!!Margin of Error','Arizona!!Percent Margin of Error','Arkansas!!Percent Margin of Error','West Virginia!!Margin of Error','West Virginia!!Percent Margin of Error','Wisconsin!!Margin of Error','Washington!!Percent Margin of Error'])
demo_state
# Out:
#                                       Label (Grouping) Alabama!!Estimate  \
# 0                                   HOUSEHOLDS BY TYPE               NaN
# 1                                     Total households         2,016,448
# 2                             Married-couple household           941,596
# 3                With children of the householder u...           332,042
# 4                          Cohabiting couple household            94,735
# ..                                                 ...               ...
# 167          West Indian (excluding Hispanic origin...            12,642
# 168                         COMPUTERS AND INTERNET USE               NaN
# 169                                   Total households         2,016,448
# 170                                    With a computer         1,896,102
# 171             With a broadband Internet subscription         1,763,106
#
#     Alabama!!Percent Alaska!!Estimate Alaska!!Percent Arizona!!Estimate  \
# ...

# %%
pd.set_option('display.max_columns', 200)

# %%
pd.set_option('display.max_rows',200 )

# %%
demo_state
# Out:
#                                       Label (Grouping) Alabama!!Estimate  \
# 0                                   HOUSEHOLDS BY TYPE               NaN
# 1                                     Total households         2,016,448
# 2                             Married-couple household           941,596
# 3                With children of the householder u...           332,042
# 4                          Cohabiting couple household            94,735
# 5                With children of the householder u...            32,210
# 6            Male householder, no spouse/partner pr...           364,410
# 7                With children of the householder u...            21,857
# 8                             Householder living alone           268,176
# 9                                    65 years and over            80,694
# 10           Female householder, no spouse/partner ...           615,707
# 11               With children of the householder u...           119,943
# ...

# %%
demo_state = demo_state.drop(columns =['Arkansas!!Margin of Error','Virginia!!Percent Margin of Error','Washington!!Margin of Error','California!!Margin of Error','California!!Percent Margin of Error','Colorado!!Margin of Error','Colorado!!Percent Margin of Error','Connecticut!!Margin of Error'])

# %%
demo_state.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Estimate', 'Alabama!!Percent',
#        'Alaska!!Estimate', 'Alaska!!Percent', 'Arizona!!Estimate',
#        'Arizona!!Percent', 'Arkansas!!Estimate', 'Arkansas!!Percent',
#        'California!!Estimate',
#        ...
#        'Virginia!!Margin of Error', 'Virginia!!Percent',
#        'Washington!!Estimate', 'Washington!!Percent',
#        'West Virginia!!Estimate', 'West Virginia!!Percent',
#        'Wisconsin!!Estimate', 'Wisconsin!!Percent', 'Wyoming!!Estimate',
#        'Wyoming!!Percent'],
#       dtype='object', length=183)

# %%
demo_state = demo_state.drop(columns = ['Virginia!!Margin of Error','Connecticut!!Percent Margin of Error','Delaware!!Margin of Error','Delaware!!Percent Margin of Error','District of Columbia!!Margin of Error','District of Columbia!!Percent Margin of Error','Florida!!Margin of Error','Florida!!Percent Margin of Error','Georgia!!Margin of Error','Georgia!!Margin of Error','Hawaii!!Margin of Error','Hawaii!!Percent Margin of Error','Idaho!!Margin of Error','Idaho!!Percent Margin of Error','Illinois!!Margin of Error','Illinois!!Percent Margin of Error','Indiana!!Margin of Error','Indiana!!Percent Margin of Error','Iowa!!Margin of Error','Iowa!!Percent Margin of Error','Kansas!!Margin of Error','Kansas!!Percent Margin of Error','Kentucky!!Margin of Error','Kentucky!!Percent Margin of Error','Louisiana!!Margin of Error','Louisiana!!Percent Margin of Error','Maine!!Margin of Error','Maine!!Percent Margin of Error','Maryland!!Margin of Error','Maryland!!Percent Margin of Error','Massachusetts!!Margin of Error','Massachusetts!!Percent Margin of Error','Michigan!!Percent Margin of Error','Michigan!!Margin of Error','Minnesota!!Margin of Error','Minnesota!!Percent Margin of Error','Mississippi!!Margin of Error','Mississippi!!Percent Margin of Error','Missouri!!Margin of Error','Missouri!!Percent Margin of Error','Montana!!Margin of Error','Montana!!Percent Margin of Error','Nebraska!!Margin of Error','Nebraska!!Percent Margin of Error','Nevada!!Margin of Error','Nevada!!Percent Margin of Error','New Hampshire!!Margin of Error'])

# %%
demo_state=demo_state.drop(columns = ['New Hampshire!!Percent Margin of Error','New Jersey!!Margin of Error','New Jersey!!Percent Margin of Error','New Mexico!!Margin of Error','New Mexico!!Percent Margin of Error','New York!!Margin of Error','New York!!Percent Margin of Error','North Carolina!!Margin of Error','North Carolina!!Percent Margin of Error','North Dakota!!Margin of Error','North Dakota!!Percent Margin of Error','Ohio!!Margin of Error','Ohio!!Percent Margin of Error','Oklahoma!!Margin of Error','Oklahoma!!Percent Margin of Error','Oregon!!Margin of Error','Oregon!!Percent Margin of Error','Pennsylvania!!Margin of Error','Pennsylvania!!Percent Margin of Error','Rhode Island!!Margin of Error','Rhode Island!!Percent Margin of Error','South Carolina!!Margin of Error','South Carolina!!Percent Margin of Error','South Dakota!!Margin of Error','South Dakota!!Percent Margin of Error','Tennessee!!Margin of Error','Tennessee!!Percent Margin of Error','Texas!!Margin of Error','Texas!!Percent Margin of Error','Utah!!Margin of Error','Utah!!Percent Margin of Error','Vermont!!Margin of Error','Vermont!!Percent Margin of Error'])

# %%
demo_state=demo_state.drop(columns = ['Georgia!!Percent Margin of Error'])

# %%
demo_state
# Out:
#                                       Label (Grouping) Alabama!!Estimate  \
# 0                                   HOUSEHOLDS BY TYPE               NaN
# 1                                     Total households         2,016,448
# 2                             Married-couple household           941,596
# 3                With children of the householder u...           332,042
# 4                          Cohabiting couple household            94,735
# 5                With children of the householder u...            32,210
# 6            Male householder, no spouse/partner pr...           364,410
# 7                With children of the householder u...            21,857
# 8                             Householder living alone           268,176
# 9                                    65 years and over            80,694
# 10           Female householder, no spouse/partner ...           615,707
# 11               With children of the householder u...           119,943
# ...

# %% [markdown]
# df.to_csv('data.csv')

# %%
demo_state.to_csv('demo_state.csv')

# %%
house_type = pd.read_csv('data/demo_state.csv', nrows= 18)
print(house_type.columns)
# Out:
# Index(['Unnamed: 0', 'Label (Grouping)', 'Alabama!!Estimate',
#        'Alabama!!Percent', 'Alaska!!Estimate', 'Alaska!!Percent',
#        'Arizona!!Estimate', 'Arizona!!Percent', 'Arkansas!!Estimate',
#        'Arkansas!!Percent',
#        ...
#        'Virginia!!Estimate', 'Virginia!!Percent', 'Washington!!Estimate',
#        'Washington!!Percent', 'West Virginia!!Estimate',
#        'West Virginia!!Percent', 'Wisconsin!!Estimate', 'Wisconsin!!Percent',
#        'Wyoming!!Estimate', 'Wyoming!!Percent'],
#       dtype='object', length=104)

# %%
house_type =house_type.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# text = "Wisconsin!!Percent"
# cleaned_text = text.replace("!!", "!")
# print(cleaned_text)

# %%
house_type.columns = [col.replace('!!', '') for col in house_type.columns]

# %%
house_type
# Out:
#                                      Label (Grouping) AlabamaEstimate  \
# 0                                  HOUSEHOLDS BY TYPE             NaN
# 1                                    Total households       2,016,448
# 2                            Married-couple household         941,596
# 3               With children of the householder u...         332,042
# 4                         Cohabiting couple household          94,735
# 5               With children of the householder u...          32,210
# 6           Male householder, no spouse/partner pr...         364,410
# 7               With children of the householder u...          21,857
# 8                            Householder living alone         268,176
# 9                                   65 years and over          80,694
# 10          Female householder, no spouse/partner ...         615,707
# 11              With children of the householder u...         119,943
# ...

# %%
house_type.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Estimate', 'Alabama!!Percent',
#        'Alaska!!Estimate', 'Alaska!!Percent', 'Arizona!!Estimate',
#        'Arizona!!Percent', 'Arkansas!!Estimate', 'Arkansas!!Percent',
#        'California!!Estimate',
#        ...
#        'Virginia!!Estimate', 'Virginia!!Percent', 'Washington!!Estimate',
#        'Washington!!Percent', 'West Virginia!!Estimate',
#        'West Virginia!!Percent', 'Wisconsin!!Estimate', 'Wisconsin!!Percent',
#        'Wyoming!!Estimate', 'Wyoming!!Percent'],
#       dtype='object', length=103)

# %%
marry_status =pd.read_csv('data/demo_state.csv', skiprows= 27, nrows = 12)
marry_status =marry_status.drop(columns = ['26'])

# %%
marry_status.columns = ['AlabamaEstimate','AlabamaPercent','AlaskaEstimate','AlaskaPercent','ArizonaEstimate'.'ArizonaPercent','ArkansasEstimate','ArkansasPercent','CaliforniaEstimate','CaliforniaPercent','ColoradoEstimate','ColoradoPercent','ConnecticutEstimate','ConnecticutPercent	DelawareEstimate	DelawarePercent	District of ColumbiaEstimate	District of ColumbiaPercent	FloridaEstimate	FloridaPercent	GeorgiaEstimate	GeorgiaPercent	HawaiiEstimate	HawaiiPercent	IdahoEstimate	IdahoPercent	IllinoisEstimate	IllinoisPercent	IndianaEstimate	IndianaPercent	IowaEstimate	IowaPercent	KansasEstimate	KansasPercent	KentuckyEstimate	KentuckyPercent	LouisianaEstimate	LouisianaPercent	MaineEstimate	MainePercent	MarylandEstimate	MarylandPercent	MassachusettsEstimate	MassachusettsPercent	MichiganEstimate	MichiganPercent	MinnesotaEstimate	MinnesotaPercent	MississippiEstimate	MississippiPercent	MissouriEstimate	MissouriPercent	MontanaEstimate	MontanaPercent	NebraskaEstimate	NebraskaPercent	NevadaEstimate	NevadaPercent	New HampshireEstimate	New HampshirePercent	New JerseyEstimate	New JerseyPercent	New MexicoEstimate	New MexicoPercent	New YorkEstimate	New YorkPercent	North CarolinaEstimate	North CarolinaPercent	North DakotaEstimate	North DakotaPercent	OhioEstimate	OhioPercent	OklahomaEstimate	OklahomaPercent	OregonEstimate	OregonPercent	PennsylvaniaEstimate	PennsylvaniaPercent	Rhode IslandEstimate	Rhode IslandPercent	South CarolinaEstimate	South CarolinaPercent	South DakotaEstimate	South DakotaPercent	TennesseeEstimate	TennesseePercent	TexasEstimate	TexasPercent	UtahEstimate	UtahPercent	VermontEstimate	VermontPercent	VirginiaEstimate	VirginiaPercent	WashingtonEstimate	WashingtonPercent	West VirginiaEstimate	West VirginiaPercent	WisconsinEstimate	WisconsinPercent	WyomingEstimate	WyomingPercen]

# %%
education = pd.read_csv('data/demo_state.csv', skiprows= 66, nrows = 10)
education.drop(columns = ['65'])
# Out:
#                               EDUCATIONAL ATTAINMENT Unnamed: 2 Unnamed: 3  \
# 0                       Population 25 years and over  3,474,924  3,474,924
# 1                                Less than 9th grade    118,034      3.40%
# 2                      9th to 12th grade, no diploma    271,263      7.80%
# 3          High school graduate (includes equival...  1,057,155     30.40%
# 4                            Some college, no degree    716,144     20.60%
# 5                                 Associate's degree    311,537      9.00%
# 6                                  Bachelor's degree    609,316     17.50%
# 7                    Graduate or professional degree    391,475     11.30%
# 8                     High school graduate or higher  3,085,627     88.80%
# 9                        Bachelor's degree or higher  1,000,791     28.80%
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0    489,218    489,218  5,053,656  5,053,656  2,057,624  2,057,624
# ...

# %%
pd.read_csv('data/house holds by race.csv', skiprows = 7, nrows= 58)
# Out:
#      Year Total households   White1  \
# 0     NaN              NaN      NaN
# 1     NaN              NaN      NaN
# 2    2023          131,434  101,420
# 3    2022          131,202  102,057
# 4   2021r          129,244  100,931
# 5    2021          129,931  101,582
# 6    2020          128,451  100,568
# 7    2019          128,579  100,528
# 8    2018          127,586  100,065
# 9    2017          126,224   99,400
# 10   2016          125,819   99,313
# 11   2015          124,587   98,679
# 12  2014s          123,229   98,052
# 13   2013          122,459   97,705
# 14   2012          121,084   96,964
# 15  2011r          119,927   96,306
# 16   2011          118,682   96,144
# 17   2010          117,538   95,489
# 18   2009          117,181   95,297
# 19   2008          116,783   95,112
# 20   2007          116,011   94,705
# 21   2006          114,384   93,588
# 22   2005          113,343   92,880
# 23   2004          112,000   91,962
# 24   2003          111,278   91,645
# ...
